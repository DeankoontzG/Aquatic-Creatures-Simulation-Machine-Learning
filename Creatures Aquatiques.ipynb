# %%
import pygame
import numpy as np
import sys
import math

# =======================
# CLASSES
# =======================

class Point:
    def __init__(self, x, y, vx=0.0, vy=0.0):
        self.x = x
        self.y = y
        self.vx = vx
        self.vy = vy
        self.radius = 10
        self.connected_points = []  # Liste des points reliés à ce point

    def update_position(self, dt):
        # Résistance fluide simple
        damping = 0.9  # ou un peu moins pour plus de réalisme
        self.vx *= damping
        self.vy *= damping
        self.x += self.vx * dt
        self.y += self.vy * dt

    def connect(self, other_point):
        self.connected_points.append(other_point)

class Membre:
    def __init__(self, Pa, Pb, length=100.0, stiffness=100.0):
        self.Pa = Pa
        self.Pb = Pb
        Pa.connect(Pb)
        Pb.connect(Pa)
        self.length = length
        self.stiffness = stiffness

    def avoid_stretch(self):
        dx = self.Pb.x - self.Pa.x
        dy = self.Pb.y - self.Pa.y
        dist = np.hypot(dx, dy)
        if dist == 0:
            return
        force_mag = self.stiffness * (dist - self.length)

        fx = force_mag * (dx / dist)
        fy = force_mag * (dy / dist)

        self.Pa.vx += fx / 2
        self.Pa.vy += fy / 2
        self.Pb.vx -= fx / 2
        self.Pb.vy -= fy / 2

class Articulation:
    def __init__(self, Porigin, Pa, Pb, Angle1, Angle2, Angle3, Timing):
        self.Porigin = Porigin
        self.Pa = Pa
        self.Pb = Pb
        self.Angle1 = Angle1
        self.Angle2 = Angle2
        self.Angle3 = Angle3
        self.Timing = Timing

    # Calcul de la variation de volume d'eau dans l'articulation entre T et T+1
    def volume_change(self, dt):
        # Calcul de l'aire à T 
        aire = 0.5 * np.abs(
            self.Pa.x * (self.Pb.y - self.Porigin.y) +
            self.Pb.x * (self.Porigin.y - self.Pa.y) +
            self.Porigin.x * (self.Pa.y - self.Pb.y)
        )
        
        if aire < 1e-6:
            return
        
        # Calcul des nouvelles coordonnées de chaque point au temps T+1 : 
        Pa_x_futur = self.Pa.x + dt * self.Pa.vx
        Pa_y_futur = self.Pa.y + dt * self.Pa.vy
    
        Porigin_x_futur = self.Porigin.x + dt * self.Porigin.vx
        Porigin_y_futur = self.Porigin.y + dt * self.Porigin.vy
    
        Pb_x_futur = self.Pb.x + dt * self.Pb.vx
        Pb_y_futur = self.Pb.y + dt * self.Pb.vy

        aire_futur = 0.5 * np.abs( #Calcul de l'aire d'un triangle à l'aide de 3 points.
            Pa_x_futur * (Porigin_y_futur - Pb_y_futur) +
            Porigin_x_futur * (Pb_y_futur - Pa_y_futur) +                Pb_x_futur * (Pa_y_futur - Porigin_y_futur)
        )

        # Variation de l'aire = estimation de la variation de volume
        volume = aire - aire_futur
        return volume

    def appliquer_force_angulaire(self, compteur, dt):
        # Déterminer l'angle cible selon le compteur
        phase = compteur % self.Timing
        if phase < self.Timing / 3:
            angle_cible = self.Angle1
        elif phase < 2 * self.Timing / 3:
            angle_cible = self.Angle2
        else:
            angle_cible = self.Angle3

        # Vecteurs Porigin→Pa et Porigin→Pb
        vectA = np.array([self.Pa.x - self.Porigin.x, self.Pa.y - self.Porigin.y])
        vectB = np.array([self.Pb.x - self.Porigin.x, self.Pb.y - self.Porigin.y])

        # Calcul du produit scalaire
        produit_scalaire = np.dot(vectA, vectB)

        # Calcul des normes des vecteurs
        normeA = np.linalg.norm(vectA)
        normeB = np.linalg.norm(vectB)

        # Calcul de l'angle entre les vecteurs en radians
        angle_actuel_rad = np.arccos(produit_scalaire / (normeA * normeB))

        # Conversion en degrés, dans l'intervalle [0, 360]
        angle_actuel_deg = np.degrees(angle_actuel_rad) % 360
        
       # Calcul de l'erreur angulaire
        erreur = (angle_cible - angle_actuel_deg)

        # Force tangentielle constante quelque soit l'erreur
        FORCE_ANGULAIRE = 50  # À ajuster selon les tests
        direction = np.sign(erreur)  # +1 ou -1 selon le sens de la correction
        force = direction * FORCE_ANGULAIRE * np.sin(angle_actuel_rad / 2) ** 0.8 #Fonction pour que le bras ait une force max pour des angles de 180°, 
        print(f"Force / angle {force} / {angle_actuel_deg}")
        
        # Tangentes unitaires (perpendiculaires aux vecteurs vers Porigin)
        tangentA = np.array([-vectA[1], vectA[0]], dtype=float)
        tangentB = np.array([vectB[1], -vectB[0]], dtype=float)
        tangentA /= np.linalg.norm(tangentA)
        tangentB /= np.linalg.norm(tangentB)

        # Appliquer les forces
        self.Pa.vx += force * tangentA[0]
        self.Pa.vy += force * tangentA[1]
        self.Pb.vx += force * tangentB[0]
        self.Pb.vy += force * tangentB[1]

        # === 3e loi de Newton : réaction de l'eau sur les bras ===
        # On applique une force opposée à celle qu'on a utilisée pour faire tourner
        

        # === Réaction sur l'origine (3ème et 2ème lois de Newton) ===
        if abs(angle_actuel_rad) > np.radians(70): #Angle ouvert, 3ème loi de Newton car eau supposée immobile
            self.Pa.vx -= force * tangentA[0] 
            self.Pa.vy -= force * tangentA[1]
            self.Pb.vx -= force * tangentB[0]
            self.Pb.vy -= force * tangentB[1]
            self.Porigin.vx -= force * (tangentA[0] + tangentB[0])/2
            self.Porigin.vy -= force * (tangentA[1] + tangentB[1])/2
            
        else : #Angle fermé, hypothèse d'eau immobile entre les bras plus acceptable donc utilisation de la 2nde loi de Newton

            variation_volume = self.volume_change(dt)

            if variation_volume <= 0:
                return

            print(f"Variation volume / distance entre les points : {variation_volume} / {np.hypot(self.Pa.x - self.Pb.x, self.Pa.y - self.Pb.y)}")

            # Calcul de la vitesse d'expulsion
            vitesse = variation_volume / (np.hypot(self.Pa.x - self.Pb.x, self.Pa.y - self.Pb.y) *100* dt) #en unité de distance/s
            print(f"vitesse : {vitesse}")

            # Force = masse × accélération ≈ variation_volume * vitesse / 100*dt
            # ρ fluide = 1, donc masse = aire
            force_prop = 0.005*variation_volume * vitesse / dt # coef d'efficacité
            print(f"Force prop : {force_prop}")
            FORCE_PROPULSION_MAX = 1000 #On ajoute une force max pour éviter les Pbs quand angle proche de 0
            force_prop = min(force_prop, FORCE_PROPULSION_MAX)

            # Direction approximative : perpendiculaire à l’ouverture
            direction = np.array([-(vectA[1] + vectB[1]), vectA[0] + vectB[0]])
            direction = direction / (np.linalg.norm(direction) + 1e-6)

            # Répartir la force sur les 3 points : 
            self.Porigin.vx -= force_prop * direction[1]/3
            self.Porigin.vy -= force_prop * direction[0]/3

            self.Pa.vx -= force_prop * direction[1]/3
            self.Pa.vy -= force_prop * direction[0]/3

            self.Pb.vx -= force_prop * direction[1]/3
            self.Pb.vy -= force_prop * direction[0]/3


class Camera:
    def __init__(self, screen_width, screen_height):
        self.screen_width = screen_width
        self.screen_height = screen_height
        self.offset_x = 0
        self.offset_y = 0

    def center_on(self, points):
        # Calcul du centre de gravité moyen des points
        avg_x = sum(p.x for p in points) / len(points)
        avg_y = sum(p.y for p in points) / len(points)
        
        self.offset_x = self.screen_width // 2 - avg_x
        self.offset_y = self.screen_height // 2 - avg_y

    def apply(self, x, y):
        return int(x + self.offset_x), int(y + self.offset_y)


# =======================
# INITIALISATION
# =======================

pygame.init()
font = pygame.font.SysFont("Arial", 24)
width, height = 800, 600
screen = pygame.display.set_mode((width, height))
pygame.display.set_caption("Simulation Aquatique")
clock = pygame.time.Clock()

# Couleurs
BLUE = (0, 191, 255)
WHITE = (255, 255, 255)
LIGHT_BLUE = (173, 216, 230)
GRID_COLOR = (200, 230, 255)

# Caméra
camera = None
#camera = Camera(width, height)

# Objets
p1 = Point(300, 300)
p2 = Point(300, 400)
p3 = Point(300, 500)

# Membre
membre1 = Membre(p1, p2)
membre2 = Membre(p3, p2)

#Articulations
Ar1An1_deg= 20
Ar1An2_deg= 20
Ar1An3_deg= 220
Ar1Timing = 400
Ar2An1_deg= 90
Ar2An2_deg= 10
Ar2An3_deg= 160
Ar2Timing = 100
articulation1 = Articulation(p2, p1, p3, Ar1An1_deg, Ar1An2_deg, Ar1An3_deg, Ar1Timing)
#articulation2 = Articulation(p3, p4, p5, Ar2An1_deg, Ar2An2_deg, Ar2An3_deg, Ar2Timing)

# Simulation
dt = 0.01
compteur = 0 #compteur de temps (en centièmes de secondes)
running = True
simulation_active = False

# =======================
# BOUCLE PRINCIPALE
# =======================
while running:
    screen.fill(LIGHT_BLUE)

    # === Événements ===
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False

        if event.type == pygame.KEYDOWN:
            if event.key == pygame.K_RETURN:
                simulation_active = not simulation_active
            if event.key == pygame.K_c:  # Fermer l'application avec la touche "C"
                running = False

    # === Caméra centrée sur le centre de gravité des points ===
    #camera.center_on([p1, p2, p3])

    # === Grille fixe ===
    spacing = 50
    #grid_offset_x = p1.x - width // 2  # Décalage de la grille par rapport à l'objet
    #grid_offset_y = p1.y - height // 2
    grid_offset_x = 0
    grid_offset_y = 0
    for x in range(0, 3*width + spacing, spacing):
        pygame.draw.line(screen, GRID_COLOR, (x - grid_offset_x, 0), (x - grid_offset_x, height), 1)
    for y in range(0, 3*height + spacing, spacing):
        pygame.draw.line(screen, GRID_COLOR, (0, y - grid_offset_y), (width, y - grid_offset_y), 1)
        

    # === Physique ===
    if simulation_active:
        # Appliquer la force de correction d'étirement
        membre1.avoid_stretch()
        membre2.avoid_stretch()
        articulation1.appliquer_force_angulaire(compteur, dt)

        # Mettre à jour les positions
        p1.update_position(dt)
        p2.update_position(dt)
        p3.update_position(dt)

        # Calcul de la vitesse de Porigin
        vx = p2.vx
        vy = p2.vy
        speed = math.hypot(vx, vy)

        # Affichage de la vitesse
        speed_text = font.render(f"Vitesse : {speed:.2f}px/s", True, (0, 0, 0))
        screen.blit(speed_text, (10, 40))

    # === Dessin des objets ===
    """
    pygame.draw.line(screen, BLUE, camera.apply(p1.x, p1.y), camera.apply(p2.x, p2.y), 10)
    pygame.draw.line(screen, BLUE, camera.apply(p2.x, p2.y), camera.apply(p3.x, p3.y), 10)

    pygame.draw.circle(screen, WHITE, camera.apply(p1.x, p1.y), p1.radius)
    pygame.draw.circle(screen, WHITE, camera.apply(p2.x, p2.y), p2.radius)
    pygame.draw.circle(screen, WHITE, camera.apply(p3.x, p3.y), p3.radius)
    """

    pygame.draw.line(screen, BLUE, (p1.x, p1.y), (p2.x, p2.y), 10)  
    pygame.draw.line(screen, BLUE, (p2.x, p2.y), (p3.x, p3.y), 10)

    pygame.draw.circle(screen, WHITE, (p1.x, p1.y), p1.radius)
    pygame.draw.circle(screen, WHITE, (p2.x, p2.y), p2.radius)
    pygame.draw.circle(screen, WHITE, (p3.x, p3.y), p3.radius)

    # Affichage du timer
    timer_text = font.render(f"Temps : {compteur / 100:.2f}s", True, (0, 0, 0))
    screen.blit(timer_text, (10, 10))

    # === Mise à jour de l'affichage ===
    pygame.display.flip()
    clock.tick(100)
    compteur +=1

# =======================
# FERMETURE
# =======================
pygame.quit()
sys.exit()
# Out:
# Force / angle -50.0 / 180.0
# Force / angle -49.99959500574078 / 179.4843414650581
# Force / angle -49.99659439985542 / 178.50467466838984
# Force / angle -49.98726074200287 / 177.10789333021867
# Force / angle -49.96688822425362 / 175.33726377021637
# Force / angle -49.930276927572905 / 173.23370209652987
# Force / angle -49.87214597700989 / 170.83692847972264
# Force / angle -49.787502042439044 / 168.1861392516139
# Force / angle -49.67194946709726 / 165.31998274846043
# Force / angle -49.52191506333443 / 162.27595530330697
# Force / angle -49.33477691347654 / 159.0896471552726
# Force / angle -49.108921684997746 / 155.79434510541893
# Force / angle -48.84377831505061 / 152.42125083741544
# Force / angle -48.53985957971004 / 149.00011679116284
# Force / angle -48.19878854734132 / 145.5597133905148
# Force / angle -47.82323338187205 / 142.12751143311286
# Force / angle -47.4166756671645 / 138.72839666913654
# Force / angle -46.98301890466996 / 135.38292747220058
# Force / angle -46.5261645692254 / 132.10615279583502
# Force / angle -46.0497494076153 / 128.90789833265433
# Force / angle -45.5571700692278 / 125.79462810217206
# Force / angle -45.05183318979832 / 122.7719315065141
# Force / angle -44.53738620108594 / 119.84612008971762
# Force / angle -44.017665586719104 / 117.02388799190666
# Force / angle -43.49630266162109 / 114.31032727988148
# Force / angle -42.976224164778706 / 111.7068746663865
# Force / angle -42.45942976062582 / 109.21094960699455
# Force / angle -41.94725921219176 / 106.81782549458539
# Force / angle -41.44097476587584 / 104.52349644934792
# Force / angle -40.94219603168378 / 102.32639952438917
# Force / angle -40.45281426139976 / 100.22668869040504
# Force / angle -39.974448462717596 / 98.22375937350564
# Force / angle -39.50792354256233 / 96.31421316600071
# Force / angle -39.05325836026326 / 94.4920787055657
# Force / angle -38.610206740785635 / 92.75111892237294
# Force / angle -38.178884977945984 / 91.08719314747606
# Force / angle -37.7599265243367 / 89.49860791132828
# Force / angle -37.35403931401047 / 87.98425168049243
# Force / angle -36.9614050858823 / 86.54134521827056
# Force / angle -36.58150836608635 / 85.16492893895918
# Force / angle -36.21356197038104 / 83.84949261977879
# Force / angle -35.85711316223891 / 82.5911026138541
# Force / angle -35.51224571598317 / 81.38797928748545
# Force / angle -35.179205930842414 / 80.23907492240947
# Force / angle -34.85785645738685 / 79.14217135376018
# Force / angle -34.54751711739835 / 78.09339504683273
# Force / angle -34.24733837617634 / 77.08852635046769
# Force / angle -33.956807139105656 / 76.12466841575755
# Force / angle -33.67586900002032 / 75.20057617494352
# Force / angle -33.404570141759635 / 74.31541666012146
# Force / angle -33.14262110825559 / 73.46734192057959
# Force / angle -32.88934086352317 / 72.65334303015439
# Force / angle -32.644015324742924 / 71.87042399143255
# Force / angle -32.406269062687585 / 71.1167671474233
# Force / angle -32.17606130604054 / 70.39167597011452
# Force / angle -31.953339909366623 / 69.69445700142508
# Variation volume / distance entre les points : 45.06890501737507 / 114.42955878053806
# vitesse : 0.39385719474643555
# Force prop : 8.875356250218449
# Force / angle -31.665861256625195 / 68.80063982872304
# Variation volume / distance entre les points : 52.273407819400745 / 112.98880088235444
# vitesse : 0.462642380582732
# Force prop : 12.091946917369778
# Force / angle -31.297396108702596 / 67.66488582923095
# Variation volume / distance entre les points : 49.46232527131724 / 111.22430238667505
# vitesse : 0.4447078939579211
# Force prop : 10.998143250834573
# Force / angle -30.837896310778955 / 66.2636272337726
# Variation volume / distance entre les points : 51.45803804778188 / 109.22630283446529
# vitesse : 0.47111397815751027
# Force prop : 12.121300506435524
# Force / angle -30.301765696025925 / 64.64917881384562
# Variation volume / distance entre les points : 66.52260943745205 / 107.00246464481108
# vitesse : 0.6216923101563152
# Force prop : 20.678297369397928
# Force / angle -29.717188451911525 / 62.91309050989814
# Variation volume / distance entre les points : 87.90198308468825 / 104.51334885099618
# vitesse : 0.8410598650896679
# Force prop : 36.965415017161085
# Force / angle -29.100367423420526 / 61.10762355812102
# Variation volume / distance entre les points : 102.61146902408655 / 101.75249790082023
# vitesse : 1.0084417694011165
# Force prop : 51.73884569174884
# Force / angle -28.444545822365374 / 59.21655240478563
# Variation volume / distance entre les points : 106.46547112619828 / 98.7792945576731
# vitesse : 1.0778116163204379
# Force prop : 57.374860758422344
# Force / angle -27.735223410162625 / 57.20302683757867
# Variation volume / distance entre les points : 107.74656009280443 / 95.6736537038596
# vitesse : 1.1261884115590934
# Force prop : 60.67146368093591
# Force / angle -26.97280682044966 / 55.07417159404924
# Variation volume / distance entre les points : 116.3261699835075 / 92.47147451430851
# vitesse : 1.2579681528221751
# Force prop : 73.16730858951564
# Force / angle -26.175984795505812 / 52.88685147232474
# Variation volume / distance entre les points : 132.03336894879794 / 89.15588043501532
# vitesse : 1.480927206422862
# Force prop : 97.7659041159712
# Force / angle -25.36307261707092 / 50.69340817195755
# Variation volume / distance entre les points : 145.8480989129148 / 85.70808180002473
# vitesse : 1.701684320192926
# Force prop : 124.09371152502702
# Force / angle -24.535173044274337 / 48.49753531972823
# Variation volume / distance entre les points : 151.41901240578682 / 82.15236056006938
# vitesse : 1.8431486493327236
# Force prop : 139.54387409951042
# Force / angle -23.681078881580824 / 46.27095867218274
# Variation volume / distance entre les points : 152.1345281961003 / 78.54391275797025
# vitesse : 1.9369359490008655
# Force prop : 147.33741837365622
# Force / angle -22.796293523404188 / 44.00451795007886
# Variation volume / distance entre les points : 155.7067315725717 / 74.92116617000704
# vitesse : 2.0782742652356805
# Force prop : 161.8006465756179
# Force / angle -21.891859921500302 / 41.728675014165944
# Variation volume / distance entre les points : 164.26270977560125 / 71.28360452051015
# vitesse : 2.304354709340471
# Force prop : 189.25977442021687
# Force / angle -20.982978838300333 / 39.48217010450999
# Variation volume / distance entre les points : 172.52245194085026 / 67.61804403063252
# vitesse : 2.551426241532418
# Force prop : 220.08915556770037
# Force / angle -20.073624363463487 / 37.27417681586827
# Variation volume / distance entre les points : 175.3117291182807 / 63.93474817706351
# vitesse : 2.742041442515191
# Force prop : 240.35601330066146
# Force / angle -19.156740815009172 / 35.08727942855286
# Variation volume / distance entre les points : 173.87202008542772 / 60.26831448409689
# vitesse : 2.884965700033102
# Force prop : 250.80740707096277
# Force / angle -18.227965173971278 / 32.91168381643005
# Variation volume / distance entre les points : 173.27033595342618 / 56.64789030251177
# vitesse : 3.058725312242447
# Force prop : 264.99318122074857
# Force / angle -17.294003126897543 / 30.76372694894596
# Variation volume / distance entre les points : 175.49785661759597 / 53.07816065995132
# vitesse : 3.3064042618570446
# Force prop : 290.13343053359796
# Force / angle -16.36566560409924 / 28.66797044831541
# Variation volume / distance entre les points : 177.5810794317017 / 49.55267375937285
# vitesse : 3.583683098394108
# Force prop : 318.1971564769855
# Force / angle -15.446567246542314 / 26.63156319354471
# Variation volume / distance entre les points : 176.2573516066027 / 46.077258029118184
# vitesse : 3.8252569520351702
# Force prop : 337.1148297902322
# Force / angle -14.532550456812787 / 24.644526026627545
# Variation volume / distance entre les points : 172.1626105302921 / 42.6726548232017
# vitesse : 4.034494953350897
# Force prop : 347.2945916700898
# Force / angle -13.620905737787314 / 22.70084078415314
# Variation volume / distance entre les points : 168.3019991233882 / 39.35715883038608
# vitesse : 4.276274104253913
# Force prop : 359.8527402727549
# Force / angle -12.716011515501293 / 20.80982655776168
# Variation volume / distance entre les points : 165.8486052449216 / 36.134920843656914
# vitesse : 4.589704401525886
# Force prop : 380.59803673977285
# Force / angle 11.824697459571809 / 18.98524998054566
# Variation volume / distance entre les points : 140.6581883099525 / 33.00338189106765
# vitesse : 4.2619325732803635
# Force prop : 299.7378572283949
# Force / angle 11.071963274313456 / 17.474527296495133
# Variation volume / distance entre les points : 116.92344189100595 / 30.38626366465769
# vitesse : 3.8479045394119904
# Force prop : 224.95512140803794
# Force / angle 10.441341314570174 / 16.23075001902936
# Variation volume / distance entre les points : 94.65971089696086 / 28.225352235021774
# vitesse : 3.3537122976806613
# Force prop : 158.73071826501686
# Force / angle 9.918198279783958 / 15.214505268338971
# Variation volume / distance entre les points : 75.22793461696347 / 26.470205965525793
# vitesse : 2.8419852386089723
# Force prop : 106.89833985622555
# Force / angle 9.493131789528055 / 14.39943794088246
# Variation volume / distance entre les points : 59.107792933444216 / 25.070305311764173
# vitesse : 2.357681416257346
# Force prop : 69.67867247758434
# Force / angle 9.159501096145119 / 13.766548417720777
# Variation volume / distance entre les points : 45.18561439871519 / 23.977839460447512
# vitesse : 1.8844739732806546
# Force prop : 42.575557150537186
# Force / angle 8.90913848361367 / 13.295651384648256
# Variation volume / distance entre les points : 32.12733893695895 / 23.154507635976188
# vitesse : 1.3875198489231217
# Force prop : 22.288660234055605
# Force / angle 8.731744962091607 / 12.96412633987359
# Variation volume / distance entre les points : 19.798452719614033 / 22.572233323199725
# vitesse : 0.8771153671916548
# Force prop : 8.68276356349544
# Force / angle 8.618043668113007 / 12.75257247738878
# Variation volume / distance entre les points : 8.988728866389465 / 22.20714284462065
# vitesse : 0.40476746285111825
# Force prop : 1.8191724887525362
# Force / angle 8.56216537280496 / 12.6488755814
# Variation volume / distance entre les points : 0.04076644042379485 / 22.034698006181884
# vitesse : 0.001850102071394749
# Force prop : 3.7711037935726736e-05
# Force / angle 8.560309183110794 / 12.645434007744996
# Force / angle 8.607775288995006 / 12.733503370049398
# Force / angle 8.69829555024883 / 12.901813502486414
# Force / angle 8.826252226669453 / 13.140526747039004
# Force / angle 8.988591567121453 / 13.444712891646672
# Force / angle 9.183870401543043 / 13.812569588444306
# Force / angle 9.409842866950076 / 14.24087116946252
# Force / angle 9.662844613439542 / 14.72370166000689
# Force / angle 9.939637441839759 / 15.255870277156424
# Force / angle 10.239040603702547 / 15.836071364028575
# Force / angle 10.561093986709308 / 16.465377868121998
# Force / angle 10.904962550625335 / 17.143186136706102
# Force / angle 11.268446088968615 / 17.86615479821711
# Force / angle 11.64964531642203 / 18.631428476834554
# Force / angle 12.048381232073826 / 19.439543033132406
# Force / angle -12.465409084019589 / 20.29297097930046
# Force / angle -12.776619393721983 / 20.935276353622402
# Force / angle -12.991821927928218 / 21.38212162443951
# Force / angle -13.119569559347841 / 21.648410562678105
# Force / angle -13.168885427954894 / 21.751414648866522
# Variation volume / distance entre les points : 3.624964289367199 / 37.73785214167492
# vitesse : 0.09605645482308872
# Force prop : 0.17410060924845513
# Force / angle -13.148744004525659 / 21.70933224667345
# Variation volume / distance entre les points : 15.832497310218969 / 37.66723789066498
# vitesse : 0.42032541266166784
# Force prop : 3.3274004826912664
# Force / angle -13.066478646297567 / 21.537649595995113
# Variation volume / distance entre les points : 26.445586682415524 / 37.369644236017166
# vitesse : 0.7076756341428333
# Force prop : 9.357448662878836
# Force / angle -12.9275715302165 / 21.24848310337999
# Variation volume / distance entre les points : 35.60862568449738 / 36.87062877550284
# vitesse : 0.9657721299332996
# Force prop : 17.194909135657323
# Force / angle -12.737103029158241 / 20.85346323939362
# Variation volume / distance entre les points : 43.863789102137616 / 36.194073451960776
# vitesse : 1.2119052905265446
# Force prop : 26.579379037710588
# Force / angle -12.500840029652222 / 20.365863709343024
# Variation volume / distance entre les points : 51.486996674239435 / 35.36038002051134
# vitesse : 1.4560645740903688
# Force prop : 37.484195941834344
# Force / angle 12.224637281320453 / 19.799220915770515
# Variation volume / distance entre les points : 35.20666893366797 / 34.38765323620487
# vitesse : 1.023817144247599
# Force prop : 18.0225956230693
# Force / angle 12.037264368962369 / 19.416907721442552
# Variation volume / distance entre les points : 20.409997163311346 / 33.72753855168776
# vitesse : 0.6051433943817999
# Force prop : 6.175487481364567
# Force / angle 11.929213755664318 / 19.19721565561956
# Variation volume / distance entre les points : 6.890686388115682 / 33.346744158277716
# vitesse : 0.2066374562808764
# Force prop : 0.7119369536347423
# Force / angle 11.8918551720562 / 19.12138896609981
# Force / angle 11.918232019396434 / 19.17491898519177
# Force / angle 12.002672218781854 / 19.34651214418674
# Force / angle 12.139768926679801 / 19.625846464681157
# Force / angle -12.324038655916713 / 20.00272560064522
# Force / angle -12.427029058659917 / 20.214078829748093
# Force / angle -12.456950710048728 / 20.275578291573
# Variation volume / distance entre les points : 6.545393071179205 / 35.203981738746506
# vitesse : 0.18592763511109198
# Force prop : 0.6084847272984384
# Force / angle -12.421565109200891 / 20.202853131633905
# Variation volume / distance entre les points : 17.695266801154048 / 35.07967545847225
# vitesse : 0.5044307442952807
# Force prop : 4.463018301504854
# Force / angle -12.327596405414894 / 20.010018197989087
# Variation volume / distance entre les points : 27.54417645788635 / 34.747035021705756
# vitesse : 0.7927058075798431
# Force prop : 10.917214321585252
# Force / angle 12.180692714257729 / 19.709404783262503
# Variation volume / distance entre les points : 13.238610713048729 / 34.22905528088518
# vitesse : 0.38676529645390706
# Force prop : 2.5601175985350806
# Force / angle 12.10943778790725 / 19.56396845323847
# Variation volume / distance entre les points : 0.4487792308727876 / 33.97933642483213
# vitesse : 0.013207415979578087
# Force prop : 0.002963606992566009
# Force / angle 12.106347325877499 / 19.55766615394244
# Force / angle 12.164893011618176 / 19.67713531792929
# Force / angle 12.279053013636988 / 19.91056749243889
# Force / angle -12.443217747736734 / 20.247346927208227
# Force / angle -12.528028593015058 / 20.42183993031843
# Force / angle -12.541488564689141 / 20.44956458957695
# Variation volume / distance entre les points : 9.464301033731317 / 35.50249620912291
# vitesse : 0.26658128425626926
# Force prop : 1.2615027620800157
# Force / angle -12.490888261495638 / 20.345383692584136
# Variation volume / distance entre les points : 20.282956024862415 / 35.32357704163087
# vitesse : 0.5742044754119262
# Force prop : 5.823282062029645
# Force / angle -12.38269043018323 / 20.123026306166338
# Variation volume / distance entre les points : 29.901236079376304 / 34.94104578881286
# vitesse : 0.8557624823281574
# Force prop : 12.794178005983664
# Force / angle 12.222660849086456 / 19.795179383976357
# Variation volume / distance entre les points : 15.406886837248294 / 34.377320138653886
# vitesse : 0.4481700951414412
# Force prop : 3.452452969841493
# Force / angle 12.13987640950708 / 19.62606581752407
# Variation volume / distance entre les points : 2.44168108761005 / 34.08679569775245
# vitesse : 0.07163128823431898
# Force prop : 0.08745038088144047
# Force / angle 12.126661308914974 / 19.599100392978293
# Force / angle 12.176102884604324 / 19.70002922923253
# Force / angle 12.281947875517739 / 19.916495010468108
# Force / angle -12.438635242888916 / 20.23792850963151
# Force / angle -12.516913697266693 / 20.3989521484558
# Force / angle -12.524670576032133 / 20.4149244830528
# Variation volume / distance entre les points : 10.461121946465937 / 35.44274355842231
# vitesse : 0.29515553527119787
# Force prop : 1.5438290238232144
# Force / angle -12.468929130552258 / 20.300210148808517
# Variation volume / distance entre les points : 21.105921926011433 / 35.245381906068246
# vitesse : 0.5988280104968191
# Force prop : 6.31940861832731
# Force / angle -12.356018998985377 / 20.068300038357275
# Variation volume / distance entre les points : 30.612714120532928 / 34.846890953700836
# vitesse : 0.8784919768367965
# Force prop : 13.446511872043343
# Force / angle 12.191794109511802 / 19.732085585646107
# Variation volume / distance entre les points : 16.119067332972918 / 34.269302748018276
# vitesse : 0.47036461323698947
# Force prop : 3.790919435907399
# Force / angle 12.105218206049768 / 19.555363684289127
# Variation volume / distance entre les points : 3.1467452475339996 / 33.965564671912034
# vitesse : 0.09264516217909999
# Force prop : 0.14576536189704975
# Force / angle 12.088548437075257 / 19.521378332801294
# Force / angle 12.13469617261279 / 19.615494533858875
# Force / angle 12.237326339695265 / 19.82517277625827
# Force / angle -12.390954041773591 / 20.139989074280862
# Force / angle -12.466750054697615 / 20.29572868942856
# Force / angle -12.472524505007641 / 20.307604846318153
# Variation volume / distance entre les points : 10.781993332164348 / 35.25821777586464
# vitesse : 0.30580086040381094
# Force prop : 1.648571418922005
# Force / angle -12.415140697870152 / 20.18965599168437
# Variation volume / distance entre les points : 21.31904416786938 / 35.05508898117273
# vitesse : 0.6081583241542858
# Force prop : 6.482677086851321
# Force / angle 12.300853254216577 / 19.955215567760334
# Variation volume / distance entre les points : 7.615004445829982 / 34.65247708636241
# vitesse : 0.21975353816269863
# Force prop : 0.8367120850479092
# Force / angle 12.259720993723366 / 19.87099359388702
# Force / angle 12.284554827104431 / 19.921833348478348
# Force / angle -12.368784381996157 / 20.09448866612183
# Force / angle -12.382324464242519 / 20.122275161279862
# Variation volume / distance entre les points : 9.342911812433613 / 34.93940478052093
# vitesse : 0.26740329067203744
# Force prop : 1.2491626815516987
# Force / angle -12.332167173109921 / 20.019388150356807
# Variation volume / distance entre les points : 19.99243037924407 / 34.762832849475444
# vitesse : 0.575109355034791
# Force prop : 5.748916870492509
# Force / angle 12.224795223557338 / 19.79954389402116
# Variation volume / distance entre les points : 6.53099015638827 / 34.38537505024408
# vitesse : 0.1899351147644938
# Force prop : 0.6202321824396928
# Force / angle 12.189762886678183 / 19.72793523372058
# Force / angle 12.219830133373785 / 19.789391287975942
# Force / angle 12.308406180301768 / 19.970689700338284
# Force / angle -12.449678134774915 / 20.260626661981615
# Force / angle -12.514111877435807 / 20.39318357537903
# Variation volume / distance entre les points : 0.8875654329858662 / 35.405690572762296
# vitesse : 0.02506844009049418
# Force prop : 0.011124940441599857
# Force / angle -12.509482445654388 / 20.38365301516055
# Variation volume / distance entre les points : 12.553167609317825 / 35.389123977821896
# vitesse : 0.35471823538736935
# Force prop : 2.2264187314495505
# Force / angle -12.442655463790512 / 20.24619121146497
# Variation volume / distance entre les points : 22.961273215717938 / 35.15248105375986
# vitesse : 0.6531906860458156
# Force prop : 7.499044902130105
# Force / angle 12.31979674030295 / 19.994031409313198
# Variation volume / distance entre les points : 9.072317084889619 / 34.71912514471387
# vitesse : 0.2613060394544796
# Force prop : 1.1853256230638582
# Force / angle 12.270970077106671 / 19.8940190093677
# Force / angle 12.28885365971555 / 19.930636919260174
# Force / angle -12.366838308198863 / 20.090495722757442
# Force / angle -12.37481989566119 / 20.106873455063045
# Variation volume / distance entre les points : 10.289303658043991 / 34.91310382097447
# vitesse : 0.29471179963846605
# Force prop : 1.5161895990443983
# Force / angle 12.319723167574299 / 19.99388062295121
# Force / angle -12.332050976664535 / 20.019149938298447
# Variation volume / distance entre les points : 9.498505715504507 / 34.762649472125986
# vitesse : 0.27323883132442967
# Force prop : 1.2976803005164337
# Force / angle 12.281100507225055 / 19.91475989775886
# Force / angle 12.297129427803103 / 19.947587350707572
# Force / angle -12.373413863137555 / 20.103988140004564
# Force / angle -12.37978596446112 / 20.11706506873102
# Variation volume / distance entre les points : 10.540776442854167 / 34.93071862700981
# vitesse : 0.30176237011922286
# Force prop : 1.5904048411462721
# Force / angle -12.323246550861276 / 20.001102043742353
# Variation volume / distance entre les points : 21.08529286508974 / 34.731614117219806
# vitesse : 0.6070922242175819
# Force prop : 6.400358671873221
# Force / angle 12.210192335915696 / 19.76968733148804
# Variation volume / distance entre les points : 7.516392861529312 / 34.33393394157372
# vitesse : 0.21892023425920276
# Force prop : 0.822745243015098
# Force / angle 12.16994830292758 / 19.68745898293546
# Force / angle 12.195193076360704 / 19.73903106329587
# Force / angle 12.279340758512731 / 19.91115666068663
# Force / angle -12.416589875961725 / 20.192632746350945
# Force / angle -12.477572625723573 / 20.317988487445778
# Variation volume / distance entre les points : 1.457029986051566 / 35.27641412968546
# vitesse : 0.0413032339595271
# Force prop : 0.030090025199967167
# Force / angle -12.469946560636208 / 20.30230266023489
# Variation volume / distance entre les points : 13.016671903755196 / 35.249185860876196
# vitesse : 0.36927581689773636
# Force prop : 2.4033710752745066
# Force / angle -12.400512621234606 / 20.159614115449187
# Variation volume / distance entre les points : 23.344593658807298 / 35.003703600276026
# vitesse : 0.6669178189082601
# Force prop : 7.784462743115681
# Force / angle 12.27544457281826 / 19.90317941494759
# Variation volume / distance entre les points : 9.468552492665822 / 34.56311588263668
# vitesse : 0.2739496208853814
# Force prop : 1.2969531828495675
# Force / angle 12.224502005550004 / 19.79894428944427
# Force / angle 12.240339825038314 / 19.831337143362074
# Force / angle 12.316293834375 / 19.986852537242843
# Force / angle -12.446362050995834 / 20.25380999213827
# Force / angle -12.500731767223131 / 20.365640887647096
# Variation volume / distance entre les points : 2.5556041296458716 / 35.35800529978167
# vitesse : 0.07227794973099493
# Force prop : 0.09235691340743367
# Force / angle -12.48701083091228 / 20.337405503651624
# Variation volume / distance entre les points : 14.030555745270249 / 35.30960362304711
# vitesse : 0.3973580642551392
# Force prop : 2.787577235682204
# Force / angle -12.4120485762297 / 20.183304805437327
# Variation volume / distance entre les points : 24.298114049098785 / 35.04472449313096
# vitesse : 0.69334584307722
# Force prop : 8.42349818527942
# Force / angle 12.282018037887408 / 19.916638679912023
# Variation volume / distance entre les points : 10.331078411563794 / 34.586342930901765
# vitesse : 0.29870398359848893
# Force prop : 1.5429671382012273
# Force / angle 12.2266349287928 / 19.803306021083863
# Force / angle 12.23842678498292 / 19.8274237896769
# Force / angle 12.31068948262071 / 19.97536817851399
# Force / angle -12.437448167003101 / 20.235488877739296
# Force / angle -12.488938484281615 / 20.34137174728236
# Variation volume / distance entre les points : 3.053777326560521 / 35.3163692298906
# vitesse : 0.08646917543199502
# Force prop : 0.13202880369030523
# Force / angle -12.472684177381078 / 20.307933262866023
# Variation volume / distance entre les points : 14.451177850143722 / 35.25880167212688
# vitesse : 0.4098601530626551
# Force prop : 2.961480982797779
# Force / angle -12.395445713217699 / 20.149210530504167
# Variation volume / distance entre les points : 24.650036758898295 / 34.98599339588134
# vitesse : 0.7045687249743829
# Force prop : 8.683822484894323
# Force / angle 12.263380613875205 / 19.87848369355471
# Variation volume / distance entre les points : 10.670142191813738 / 34.52082320627051
# vitesse : 0.3090929242346564
# Force prop : 1.6490327260336473
# Force / angle 12.206109870922802 / 19.761342302335468
# Force / angle 12.216170001471585 / 19.781907818636935
# Force / angle 12.28680652723769 / 19.926444489862767
# Force / angle -12.411989410570474 / 20.183183284245267
# Force / angle -12.462128419268096 / 20.286224645373174
# Variation volume / distance entre les points : 3.25089606282927 / 35.22168237011431
# vitesse : 0.0922981483016173
# Force prop : 0.15002584346007986
# Force / angle -12.444767741501185 / 20.250532855381426
# Variation volume / distance entre les points : 14.620248780489419 / 35.16032016572433
# vitesse : 0.41581671360153927
# Force prop : 3.039671899970011
# Force / angle -12.366664631991 / 20.09013938371528
# Variation volume / distance entre les points : 24.782547884236465 / 34.884510190364495
# vitesse : 0.7104169658395173
# Force prop : 8.80297123684591
# Force / angle 12.233927056128719 / 19.818219747699732
# Variation volume / distance entre les points : 10.802769170635202 / 34.41711484516122
# vitesse : 0.31387782558868343
# Force prop : 1.6953748488077212
# Force / angle 12.1759166776646 / 19.699648889467127
# Force / angle 12.185181039716634 / 19.718573979735584
# Force / angle 12.255001845138796 / 19.861335922067678
# Force / angle -12.379364708759562 / 20.116200500885842
# Force / angle -12.428889381711498 / 20.217901194554994
# Variation volume / distance entre les points : 3.332667534092252 / 35.10420904373325
# vitesse : 0.09493640862098258
# Force prop : 0.15819574340723222
# Force / angle -12.411073946834199 / 20.18130302158814
# Variation volume / distance entre les points : 14.66113740318724 / 35.0413024798504
# vitesse : 0.4183959032806429
# Force prop : 3.0670799134640725
# Force / angle -12.332665095855996 / 20.020408939376477
# Variation volume / distance entre les points : 24.796369956837225 / 34.76470484529989
# vitesse : 0.7132627780727337
# Force prop : 8.843163860766497
# Force / angle 12.199782307618674 / 19.748409621383367
# Variation volume / distance entre les points : 10.849952509211562 / 34.297162553951466
# vitesse : 0.3163513160059216
# Force prop : 1.7161983774454146
# Force / angle 12.141536759130108 / 19.629454359119904
# Force / angle 12.150468105930342 / 19.647684274953015
# Force / angle 12.219849272360653 / 19.789430421055375
# Force / angle 12.343680065237333 / 20.042993720250504
# Force / angle 12.516698986631347 / 20.39851007464426
# Force / angle 12.734327431458158 / 20.84771953870148
# Force / angle 12.992552776080716 / 21.38364288353848
# Force / angle 13.28783526212452 / 22.000330490134502
# Force / angle 13.617086903456284 / 22.692779720986277
# Force / angle 13.977674259111645 / 23.45692050920922
# Force / angle 14.367371371124207 / 24.28951063002617
# Force / angle 14.784263828506235 / 25.187933677109093
# Force / angle 15.226674468730403 / 26.150043764039804
# Force / angle 15.693153148607585 / 27.17415017844669
# Force / angle 16.182490216953198 / 28.259059440267468
# Force / angle 16.693689120175815 / 29.404032347466032
# Force / angle 17.225896431996194 / 30.60864501507664
# Force / angle 17.778348425432185 / 31.87268159981938
# Force / angle 18.350371556536103 / 33.19614712916714
# Force / angle 18.94140423976092 / 34.57933274540379
# Force / angle 19.550984663133296 / 36.02280601289691
# Force / angle 20.178700345197417 / 37.52730959219252
# Force / angle 20.82414747005193 / 39.093677357052776
# Force / angle 21.486933633234973 / 40.722852319940905
# Force / angle 22.16670076539265 / 42.41595734329432
# Force / angle 22.863122515914906 / 44.17430765543153
# Force / angle 23.57586781470481 / 45.999338386414024
# Force / angle 24.30456643727032 / 47.89253220817744
# Force / angle 25.048807055929025 / 49.85542775618696
# Force / angle 25.808155470561157 / 51.88968423789839
# Force / angle 26.58215759297797 / 53.99711163942769
# Force / angle 27.370314265947403 / 56.1796268715942
# Force / angle 28.17205017517248 / 58.43919015252974
# Force / angle 28.986703181247126 / 60.777795004291875
# Force / angle 29.813532875671143 / 63.1975152074255
# Force / angle 30.65172482233396 / 65.70054595131901
# Force / angle 31.500374731937136 / 68.28919036767759
# Force / angle 32.358461006524195 / 70.96580988454463
# Force / angle 33.157455395536346 / 73.5151986504264
# Force / angle 33.88734227654809 / 75.8954583780248
# Force / angle 34.53833718580592 / 78.06252649882613
# Force / angle 35.120238183553745 / 80.03694497933549
# Force / angle 35.65788427034151 / 81.89436965494357
# Force / angle 36.17168086984387 / 83.70083606438179
# Force / angle 36.664777932948326 / 85.46501196505832
# Force / angle 37.1278101728882 / 87.15029637315297
# Force / angle 37.55381863229647 / 88.72666639449932
# Force / angle 37.948038763795964 / 90.20860501821888
# Force / angle 38.32463011123615 / 91.64613194579351
# Force / angle 38.69560806986073 / 93.08413829993097
# Force / angle 39.06312981937815 / 94.53124974041401
# Force / angle 39.42125276617777 / 95.96398571822941
# Force / angle 39.76406125898766 / 97.35744453319509
# Force / angle 40.09223127680765 / 98.7125743145363
# Force / angle 40.41283203557679 / 100.05745934708872
# Force / angle 40.73373463074577 / 101.4254695598925
# Force / angle 41.05816288775992 / 102.83191400554882
# Force / angle 41.38375509540032 / 104.26836524510753
# Force / angle 41.70608436758813 / 105.71646157660034
# Force / angle 42.023083272636235 / 107.16737268198986
# Force / angle 42.33678695898871 / 108.63091299292795
# Force / angle 42.65156882881805 / 110.1289302237496
# Force / angle 42.97087204381896 / 111.68057811706531
# Force / angle 43.29516006862511 / 113.29185340640538
# Force / angle 43.62234983058724 / 114.95637413825328
# Force / angle 43.94991822465391 / 116.66494951609467
# Force / angle 44.27683736082385 / 118.41564778763671
# Force / angle 44.60401322343884 / 120.21722873324929
# Force / angle 44.93324341255931 / 122.08477820702294
# Force / angle 45.265724320624976 / 124.03197391394764
# Force / angle 45.60120094328986 / 126.06579314469874
# Force / angle 45.93816065004305 / 128.18665292632923
# Force / angle 46.274683900908926 / 130.3928150148921
# Force / angle 46.60923183244795 / 132.6854122813779
# Force / angle 46.94087496824117 / 135.070848849471
# Force / angle 47.26895092855295 / 137.55966641617485
# Force / angle 47.59249571932963 / 140.16331233309882
# Force / angle 47.90983268590832 / 142.89113306206244
# Force / angle 48.21849504389233 / 145.74918532263146
# Force / angle 48.51540567938404 / 148.7409785043153
# Force / angle 48.7971108669283 / 151.86910647845633
# Force / angle 49.05990330297142 / 155.13647137240318
# Force / angle 49.29979999358841 / 158.5463424121717
# Force / angle 49.512454272533645 / 162.10130391768604
# Force / angle 49.693115156408076 / 165.80170247517543
# Force / angle 49.83670705439492 / 169.64427762006477
# Force / angle 49.9380365528128 / 173.6213637726909
# Force / angle 49.992087123269165 / 177.72066744197107
# Force / angle 49.994353712752144 / 178.0745991556319
# Force / angle 49.94118266226859 / 173.78542271625398
# Force / angle 49.83009176368688 / 169.43653751520472
# Force / angle 49.660035558561965 / 165.05564281746715
# Force / angle 49.43156107012097 / 160.67209563797317
# Force / angle 49.146795400379894 / 156.3150817824253
# Force / angle 48.809241593364405 / 152.0115911310377
# Force / angle 48.423428738467614 / 147.7847783185929
# Force / angle 47.994528747046914 / 143.653273910426
# Force / angle 47.52806436710241 / 139.6316435918379
# Force / angle 47.029765585436635 / 135.7316137511888
# Force / angle 46.50551686778419 / 131.96322910758633
# Force / angle 45.961257915785566 / 128.33513452038707
# Force / angle 45.402732489353895 / 124.85377418776805
# Force / angle 44.835122767952285 / 121.52214935320428
# Force / angle 44.26275725437003 / 118.3392583465783
# Force / angle 43.68909752147358 / 115.3009991696541
# Force / angle 43.11703947993451 / 112.40226809706559
# Force / angle 42.54931853929877 / 109.63898243463404
# Force / angle 41.98869619994886 / 107.0086509237334
# Force / angle 41.437760967339635 / 104.50914497961783
# Force / angle 40.898505199932536 / 102.13675531199328
# Force / angle 40.37206313204372 / 99.8852497300168
# Force / angle 39.85888834710104 / 97.74684548212528
# Force / angle 39.35927070934782 / 95.7143673482377
# Force / angle 38.8737728099797 / 93.78279384039453
# Force / angle 38.403216212630724 / 91.9489015066956
# Force / angle 37.948251114178 / 90.20940948735738
# Force / angle 37.50893388385089 / 88.55937247966777
# Force / angle 37.084734342816056 / 86.9923025768183
# Force / angle 36.67498414071789 / 85.5018542913909
# Force / angle 36.279349375812195 / 84.08344178015503
# Force / angle 35.897887775485195 / 82.73427581672533
# Force / angle 35.530662305055635 / 81.4518792838535
# Force / angle 35.17731955507774 / 80.23260283249056
# Force / angle 34.837062859765986 / 79.07158012867131
# Force / angle 34.50903902814261 / 77.9640669202032
# Force / angle 34.19273881228509 / 76.90674138285755
# Force / angle 33.88801309339758 / 75.89766956982204
# Force / angle 33.59471633650854 / 74.9350651916703
# Force / angle 33.31236965869198 / 74.01618291518918
# Force / angle 33.04019318137676 / 73.1374519529079
# Force / angle 32.777453376407465 / 72.29560485321673
# Force / angle 32.52374540082245 / 71.48854969609812
# Force / angle 32.278921959330944 / 70.71509661443179
# Force / angle 32.04277088571332 / 69.97391414431584
# Variation volume / distance entre les points : 46.1535963159331 / 114.83102986829579
# vitesse : 0.40192617247157386
# Force prop : 9.275169156530561
# Force / angle 31.743088605842246 / 69.0400819014084
# Variation volume / distance entre les points : 53.23556474489669 / 113.33364043756706
# vitesse : 0.46972429844625846
# Force prop : 12.503019151093483
# Force / angle -31.36340124065474 / 67.86753686017357
# Variation volume / distance entre les points : 26.06612892188423 / 111.5175812944392
# vitesse : 0.23374008492043946
# Force prop : 3.0463495938741714
# Force / angle -31.10619222719815 / 67.07979565358958
# Variation volume / distance entre les points : 3.835237880171917 / 110.40968467628795
# vitesse : 0.03473642635079084
# Force prop : 0.06661122908117749
# Force / angle -30.965890201534798 / 66.65229316407358
# Force / angle -30.950269755549364 / 66.60479225109908
# Force / angle -31.057708723216678 / 66.93189186693036
# Force / angle -31.26759041592024 / 67.57348913500776
# Force / angle -31.552823059376937 / 68.45104544273235
# Force / angle -31.898926669566062 / 69.52475203455664
# Force / angle -32.30852715802758 / 70.80835092184346
# Force / angle -32.71928752448993 / 72.110073371725
# Force / angle -33.115345723452975 / 73.37940196610286
# Force / angle -33.47116842222926 / 74.53205686501761
# Force / angle -33.78246459096574 / 75.55029562138074
# Force / angle -34.071049306979624 / 76.50266700958865
# Force / angle -34.36225115418618 / 77.47211005226815
# Force / angle -34.66156636096282 / 78.47763443348174
# Force / angle -34.95372797274439 / 79.46824393591447
# Force / angle -35.222018808339406 / 80.38607072953
# Force / angle -35.46638272414137 / 81.22901749878676
# Force / angle -35.70282790389482 / 82.05113715530834
# Force / angle -35.94724186846457 / 82.90783994791354
# Force / angle -36.201344929599486 / 83.80610603598315
# Force / angle -36.45377457646807 / 84.70633578764958
# Force / angle -36.69322480832785 / 85.56773305536512
# Force / angle -36.91976137122381 / 86.38953543558176
# Force / angle -37.14399807682706 / 87.209735921655
# Force / angle -37.3765725590971 / 88.06770661729401
# Force / angle -37.618960884652466 / 88.9699788958728
# Force / angle -37.86377875424886 / 89.88992833625903
# Force / angle -38.102969359301106 / 90.79736211699797
# Force / angle -38.33545713958454 / 91.68778719264725
# Force / angle -38.56752447626479 / 92.58512991518293
# Force / angle -38.80662393161407 / 93.51885019678407
# Force / angle -39.05501248318494 / 94.49903801898853
# Force / angle -39.30875069256653 / 95.51142579469763
# Force / angle -39.562129324039965 / 96.53395974498532
# Force / angle -39.81294726005334 / 97.55797397865327
# Force / angle -40.064051027748384 / 98.59536917415286
# Force / angle -40.32042030694584 / 99.66761125683952
# Force / angle -40.584916858672386 / 100.7882680902311
# Force / angle -40.85639667810733 / 101.95439400083157
# Force / angle -41.131335098283685 / 103.15250871450326
# Force / angle -41.40708655616221 / 104.37229659204277
# Force / angle -41.6839160926518 / 105.61600775865988
# Force / angle -41.96441173724945 / 106.89675851668129
# Force / angle -42.25118637826024 / 108.22872508746022
# Force / angle -42.544932998783864 / 109.61804151629326
# Force / angle -42.84424082204869 / 111.06120947155104
# Force / angle -43.14698440341629 / 112.5510334936881
# Force / angle -43.45196165015609 / 114.084509012939
# Force / angle -43.75953500013829 / 115.66660233399196
# Force / angle -44.07100677095554 / 117.30789427771542
# Force / angle -44.38742157506258 / 119.01881859487956
# Force / angle -44.70874372964597 / 120.80512076632672
# Force / angle -45.03388804052394 / 122.66743786825751
# Force / angle -45.36138803286088 / 124.60453474735613
# Force / angle -45.69010198124884 / 126.61737582552453
# Force / angle -46.01947204953967 / 128.71122522302588
# Force / angle -46.34926230036795 / 130.8948222140492
# Force / angle -46.679055445480046 / 133.17774248119164
# Force / angle -47.007867425284424 / 135.56793984480765
# Force / angle -47.33406710548639 / 138.07088845158793
# Force / angle -47.65554570065117 / 140.69043436811916
# Force / angle -47.9699413037461 / 143.43040816701114
# Force / angle -48.27474643490945 / 146.29581627474758
# Force / angle -48.567249563620365 / 149.292940285098
# Force / angle -48.844379098579864 / 152.42843052088745
# Force / angle -49.102560899686864 / 155.70797733391512
# Force / angle -49.33766710791163 / 159.13517117034985
# Force / angle -49.54507091557361 / 162.71084329699727
# Force / angle -49.71977772803601 / 166.43279923003666
# Force / angle -49.856598578205165 / 170.29565502893595
# Force / angle -49.950354552847955 / 174.29053641776363
# Force / angle -49.99612339817997 / 178.404618209092
# Force / angle -49.98953942560871 / 177.37928869541648
# Force / angle -49.927132384768186 / 173.08278503937532
# Force / angle -49.80665550300304 / 168.73130939135672
# Force / angle -49.62733052995795 / 164.3528876665086
# Force / angle -49.3899456897717 / 159.97640295494023
# Force / angle -49.09678225110785 / 155.6297776965109
# Force / angle -48.75139983353849 / 151.33850845407974
# Force / angle -48.35835137660313 / 147.12485758681137
# Force / angle -47.9229021954948 / 143.00772851082112
# Force / angle -47.45079099954354 / 139.00295663775353
# Force / angle -46.94801874594694 / 135.12359917060218
# Force / angle -46.42062336143607 / 131.37991325183836
# Force / angle -45.874421103835644 / 127.77903607209396
# Force / angle -45.314755721000374 / 124.32471927846228
# Force / angle -44.74634300637826 / 121.01756319970808
# Force / angle -44.173277835362896 / 117.85592114566238
# Force / angle -43.59917951004899 / 114.83715374346488
# Force / angle -43.02735308519672 / 111.95857768131657
# Force / angle -42.4608281606785 / 109.21758953835977
# Force / angle -41.90223649666635 / 106.61102430251111
# Force / angle -41.353637473424214 / 104.13440513778075
# Force / angle -40.81646765928532 / 101.78184499675683
# Force / angle -40.291702283286206 / 99.54682656580128
# Force / angle -39.780133973608514 / 97.4233236072276
# Force / angle -39.28255920335637 / 95.40639447366486
# Force / angle -38.79973286424951 / 93.49180635716608
# Force / angle -38.33215732573121 / 91.67508972719727
# Force / angle -37.87992721136625 / 89.9509204850816
# Force / angle -37.44280180441334 / 88.31340965651071
# Force / angle -37.02046064119372 / 86.75702762320958
# Force / angle -36.612719211388495 / 85.27730036448263
# Force / angle -36.21951791125256 / 83.87065073018618
# Force / angle -35.840717499582155 / 82.5335877453177
# Force / angle -35.475921374788136 / 81.26205878151858
# Force / angle -35.12451138655608 / 80.05157976875918
# Force / angle -34.78586421884103 / 78.89796580530319
# Force / angle -34.459533988985825 / 77.79790273646914
# Force / angle -34.145227678578046 / 76.74880187042287
# Force / angle -33.842616504281665 / 75.74812988682137
# Force / angle -33.55119059243119 / 74.79292003891524
# Force / angle -33.270308105133076 / 73.87993765631211
# Force / angle -32.999380008116056 / 73.0062721354201
# Force / angle -32.737993543847985 / 72.1697070441071
# Force / angle -32.48585278300688 / 71.368497908376
# Force / angle -32.24261361589352 / 70.60083048891366
# Force / angle -32.00779612126761 / 69.8645438229938
# Variation volume / distance entre les points : 46.02471845842956 / 114.67224792935872
# vitesse : 0.40135882298899433
# Force prop : 9.236213414437566
# Force / angle -31.709068904362304 / 68.9345441134261
# Variation volume / distance entre les points : 53.11424760697446 / 113.18131464264104
# vitesse : 0.4692845967965429
# Force prop : 12.462849136195377
# Force / angle -31.330219934525573 / 67.76561914726862
# Variation volume / distance entre les points : 50.34814921661564 / 111.37150313634106
# vitesse : 0.4520738950158498
# Force prop : 11.38054196159732
# Force / angle -30.861339017437107 / 66.33471868386789
# Variation volume / distance entre les points : 52.44631247885809 / 109.33196661690772
# vitesse : 0.4796978788703824
# Force prop : 12.579192425340747
# Force / angle -30.31680662429893 / 64.69417744447783
# Variation volume / distance entre les points : 67.5385350509132 / 107.069779240392
# vitesse : 0.6307898972993711
# Force prop : 21.301312794257754
# Force / angle -29.72457784208145 / 62.93488175104172
# Variation volume / distance entre les points : 88.84849218995623 / 104.54560474017524
# vitesse : 0.8498539217480192
# Force prop : 37.75411976451628
# Force / angle -29.10061681324581 / 61.108348202442826
# Variation volume / distance entre les points : 103.48352340290148 / 101.75322414245579
# vitesse : 1.0170048593057182
# Force prop : 52.6216230794139
# Force / angle -28.43810866154391 / 59.198132782678464
# Variation volume / distance entre les points : 107.34331666067737 / 98.75180523623419
# vitesse : 1.0870010568808395
# Force prop : 58.34114932962546
# Force / angle -27.722659923383862 / 57.16765340013262
# Variation volume / distance entre les points : 108.690333991246 / 95.6206223657897
# vitesse : 1.136682980115514
# Force prop : 61.773226375460034
# Force / angle -26.954761254160086 / 55.024216009527976
# Variation volume / distance entre les points : 117.30095664764303 / 92.39505026139364
# vitesse : 1.2695588813014165
# Force prop : 74.46023564858383
# Force / angle -26.153021312730413 / 52.824369831300174
# Variation volume / distance entre les points : 132.94806139354478 / 89.05818963685431
# vitesse : 1.4928224112308683
# Force prop : 99.23392278899051
# Force / angle -25.3355743997972 / 50.619865447534416
# Variation volume / distance entre les points : 146.6569342152943 / 85.59152318752365
# vitesse : 1.7134516217684503
# Force prop : 125.64478088739249
# Force / angle -24.503422992877383 / 48.41406834868103
# Variation volume / distance entre les points : 152.16260472386784 / 82.01938650996556
# vitesse : 1.8552029123673062
# Force prop : 141.14625371855743
# Force / angle -23.64542199256142 / 46.17883973972027
# Variation volume / distance entre les points : 152.87505989526835 / 78.39661161574895
# vitesse : 1.9500212667935966
# Force prop : 149.05480897905906
# Force / angle -22.757186519767107 / 43.905265170211656
# Variation volume / distance entre les points : 156.44287413463826 / 74.76116910875646
# vitesse : 2.092568588742344
# Force prop : 163.6837221733581
# Force / angle -21.849753661792604 / 41.62371057894305
# Variation volume / distance entre les points : 164.9295117231668 / 71.11241148317993
# vitesse : 2.3192788471556365
# Force prop : 191.25876390562416
# Force / angle -20.938189449708354 / 39.372495397361156
# Variation volume / distance entre les points : 173.07115616345527 / 67.43734505055352
# vitesse : 2.566399315300962
# Force prop : 222.08484833811872
# Force / angle -20.0263573252557 / 37.16047773715565
# Variation volume / distance entre les points : 175.76409482629515 / 63.74635578618029
# vitesse : 2.7572414557445093
# Force prop : 242.312024343235
# Force / angle -19.10723028145278 / 34.9703018393773
# Variation volume / distance entre les points : 174.2822154671394 / 60.07383615373817
# vitesse : 2.901133448863236
# Force prop : 252.80798241685386
# Force / angle -18.176545785703322 / 32.79239337141984
# Variation volume / distance entre les points : 173.6511647688012 / 56.44857912635598
# vitesse : 3.076271669834167
# Force prop : 267.09907930598405
# Force / angle -17.241026722371693 / 30.643079157231544
# Variation volume / distance entre les points : 175.8089688122609 / 52.875114700263225
# vitesse : 3.3249851051649006
# Force prop : 292.281101327584
# Force / angle -16.311383654177735 / 28.54663575514585
# Variation volume / distance entre les points : 177.78772047261737 / 49.34709455845575
# vitesse : 3.6028001661174387
# Force prop : 320.2668144261933
# Force / angle -15.391136246598048 / 26.509973437365993
# Variation volume / distance entre les points : 176.37552147111273 / 45.87043754027752
# vitesse : 3.8450804249739803
# Force prop : 339.0890325265767
# Force / angle -14.476141424706961 / 24.52314659043005
# Variation volume / distance entre les points : 172.23336390214718 / 42.46574912898484
# vitesse : 4.055818334418358
# Force prop : 349.27361755643875
# Force / angle -13.56376382701659 / 22.58029258171364
# Variation volume / distance entre les points : 168.3379220211409 / 39.15107145262573
# vitesse : 4.299701534984455
# Force prop : 361.9014108551965
# Force / angle -12.658392617066422 / 20.69072538650756
# Variation volume / distance entre les points : 165.82626853117472 / 35.93043090546735
# vitesse : 4.615204002631145
# Force prop : 382.6610291332324
# Force / angle 11.766780860258109 / 18.868020919697294
# Variation volume / distance entre les points : 140.65466433651272 / 32.80131515625044
# vitesse : 4.288080025648311
# Force prop : 301.569228327834
# Force / angle 11.013439565565225 / 17.358252321832
# Variation volume / distance entre les points : 116.95024987742954 / 30.185496754630094
# vitesse : 3.874385464916716
# Force prop : 226.55517412174547
# Force / angle 10.381945508999655 / 16.114651853560684
# Variation volume / distance entre les points : 94.74201232570886 / 28.024820121918538
# vitesse : 3.3806465809074018
# Force prop : 160.1446300185973
# Force / angle 9.857748968737274 / 15.098004707365257
# Variation volume / distance entre les points : 75.37048732499306 / 26.26881617034735
# vitesse : 2.869199998821129
# Force prop : 108.126501072009
# Force / angle 9.431484842648846 / 14.282037248773722
# Variation volume / distance entre les points : 59.291090926563356 / 24.86701412600553
# vitesse : 2.3843269089776915
# Force prop : 70.68467177942404
# Force / angle 9.096488615487937 / 13.647702338413591
# Variation volume / distance entre les points : 45.392897379747865 / 23.77175369648762
# vitesse : 1.9095308642060707
# Force prop : 43.33956928118371
# Force / angle 8.84457194803369 / 13.174779454107524
# Variation volume / distance entre les points : 32.36394370912285 / 22.944865054468323
# vitesse : 1.4105092199189133
# Force prop : 22.824820497327245
# Force / angle 8.66546800780783 / 12.840721080991496
# Variation volume / distance entre les points : 20.079858680643156 / 22.35829364666779
# vitesse : 0.8980944162362675
# Force prop : 9.016804479949482
# Force / angle 8.549957769257016 / 12.626245014358735
# Variation volume / distance entre les points : 9.316693757648864 / 21.98813361497116
# vitesse : 0.42371462356884004
# Force prop : 1.973809694214175
# Force / angle 8.492194900235752 / 12.519280023947971
# Variation volume / distance entre les points : 0.4000040628316128 / 21.809871466827303
# vitesse : 0.018340505281748992
# Force prop : 0.0036681383135421255
# Force / angle 8.488354812120544 / 12.51217578932611
# Force / angle 8.533715503581048 / 12.596148242793616
# Force / angle 8.622027541759662 / 12.759972438306253
# Force / angle 8.747712634886756 / 12.993894905032878
# Force / angle 8.907728889467762 / 13.293010047582428
# Force / angle 9.100607737449684 / 13.655464577299238
# Force / angle 9.324080523642479 / 14.077990284615135
# Force / angle 9.574495940414343 / 14.554703381467647
# Force / angle 9.848647395975668 / 15.080480556680829
# Force / angle 10.145362500416825 / 15.654031078152078
# Force / angle 10.464657598611153 / 16.27637503795252
# Force / angle 10.805676867855642 / 16.946863912502796
# Force / angle 11.16623142958842 / 17.662180705899754
# Force / angle 11.54445043837948 / 18.419528183229698
# Force / angle 11.940163168050864 / 19.219452537652664
# Force / angle -12.3541044283363 / 20.06437290446232
# Force / angle -12.66293107274774 / 20.700100873840704
# Force / angle -12.876383787501286 / 21.142154068040732
# Force / angle -13.002978254182834 / 21.40534624139544
# Force / angle -13.05168817256911 / 21.506816597321908
# Variation volume / distance entre les points : 3.656910242745653 / 37.31853654477766
# vitesse : 0.09799179124716774
# Force prop : 0.17917359255838075
# Force / angle -13.031412900985776 / 21.464566453421693
# Variation volume / distance entre les points : 15.763939815929916 / 37.24750942947958
# vitesse : 0.4232213121732518
# Force prop : 3.335817646959015
# Force / angle -12.94941653287005 / 21.293898048022008
# Variation volume / distance entre les points : 26.28876295389273 / 36.95156475435385
# vitesse : 0.7114384229370213
# Force prop : 9.351418028441318
# Force / angle -12.811146945502912 / 21.00682147982786
# Variation volume / distance entre les points : 35.381439930266424 / 36.45603858224001
# vitesse : 0.9705234388111195
# Force prop : 17.16925837560561
# Force / angle -12.621671895557013 / 20.614904224868916
# Variation volume / distance entre les points : 43.57522673060339 / 35.784576081262685
# vitesse : 1.2177097370567986
# Force prop : 26.530988942156718
# Force / angle -12.386732041519302 / 20.131322138326365
# Variation volume / distance entre les points : 51.134696522141894 / 34.95739328223624
# vitesse : 1.462772012469426
# Force prop : 37.39920146935343
# Force / angle 12.112133355509641 / 19.569465831666946
# Variation volume / distance entre les points : 34.96907250275035 / 33.992471344988644
# vitesse : 1.0287299251604924
# Force prop : 17.986865669343103
# Force / angle 11.925786585461182 / 19.19025670134931
# Variation volume / distance entre les points : 20.279423802076053 / 33.33749927225597
# vitesse : 0.6083066890069027
# Force prop : 6.168054574004329
# Force / angle 11.818244300581307 / 18.972180022465967
# Variation volume / distance entre les points : 6.866081180080073 / 32.95945273184486
# vitesse : 0.20831902871512736
# Force prop : 0.7151676812567482
# Force / angle 11.780947633824024 / 18.896680760085342
# Force / angle 11.806993356205512 / 18.94939769326106
# Force / angle 11.890735575375718 / 19.119117570139522
# Force / angle 12.02678759766076 / 19.395581198770582
# Force / angle 12.20970211139968 / 19.76868521360424
# Force / angle -12.434620038846191 / 20.22967689135084
# Force / angle -12.573670608667523 / 20.51588776860759
# Force / angle -12.635973393526397 / 20.64442640787303
# Variation volume / distance entre les points : 1.4492742537877348 / 35.83832747959957
# vitesse : 0.04043922681974242
# Force prop : 0.029303765136467572
# Force / angle -12.629279900111703 / 20.6306080034719
# Variation volume / distance entre les points : 13.107827648496823 / 35.81281249093331
# vitesse : 0.36600944569252464
# Force prop : 2.3987943659297355
# Force / angle -12.56005414112079 / 20.487819894938628
# Variation volume / distance entre les points : 23.42736695843996 / 35.56628143420983
# vitesse : 0.6586959899582329
# Force prop : 7.715756335402203
# Force / angle -12.434293819606705 / 20.229006514341208
# Variation volume / distance entre les points : 32.72596643012912 / 35.122605123483595
# vitesse : 0.9317636409677356
# Force prop : 15.2464328175625
# Force / angle 12.258045428149739 / 19.86756444953837
# Variation volume / distance entre les points : 18.069382732501253 / 34.503218710325996
# vitesse : 0.5237013649133411
# Force prop : 4.7314802000762315
# Force / angle 12.161070413578667 / 19.669329817094145
# Variation volume / distance entre les points : 4.955084606668606 / 34.16255053523241
# vitesse : 0.14504434033865077
# Force prop : 0.3593534890482254
# Force / angle 12.135459966670876 / 19.617053123098938
# Force / angle 12.173660982496713 / 19.69504161853225
# Force / angle 12.269041231000454 / 19.890070478825265
# Force / angle -12.416202192287543 / 20.191836396005282
# Force / angle -12.486300985256173 / 20.33594500532299
# Variation volume / distance entre les points : 0.02624154498516873 / 35.30821702630135
# vitesse : 0.0007432135405087492
# Force prop : 9.751535778423433e-06
# Force / angle -12.487073738438413 / 20.337534936241706
# Variation volume / distance entre les points : 11.709150220061929 / 35.30938672819775
# vitesse : 0.3316157912964008
# Force prop : 1.9414695578171308
# Force / angle -12.425067464802437 / 20.210048565603884
# Variation volume / distance entre les points : 22.08242925889499 / 35.08931843131779
# vitesse : 0.6293205524102189
# Force prop : 6.948463289883687
# Force / angle 12.306365969844297 / 19.9665095285014
# Variation volume / distance entre les points : 8.276044780579468 / 34.671656888145435
# vitesse : 0.23869770075537192
# Force prop : 0.9877364302364078
# Force / angle 12.261211393241318 / 19.874043898486377
# Force / angle 12.282575173311574 / 19.91777951832354
# Force / angle -12.363819667531335 / 20.08430245223703
# Force / angle -12.374643898044289 / 20.10651228569678
# Variation volume / distance entre les points : 9.772207640264241 / 34.911685607224285
# vitesse : 0.2799122262444434
# Force prop : 1.3676801979546613
# Force / angle 12.321911016265611 / 19.99836470186327
# Force / angle -12.336350638728133 / 20.027965023317865
# Variation volume / distance entre les points : 9.136401464169467 / 34.7784531663026
# vitesse : 0.2627029275994906
# Force prop : 1.2000797061807957
# Force / angle 12.287449500134331 / 19.92776124588911
# Force / angle 12.30546267606468 / 19.964658840585614
# Force / angle -12.383482481539335 / 20.124652013122674
# Force / angle -12.39122645306238 / 20.14054831042178
# Variation volume / distance entre les points : 10.259130221276791 / 34.97100999361214
# vitesse : 0.29336099309544506
# Force prop : 1.5048143150046263
# Force / angle -12.335867113998484 / 20.026973665842753
# Variation volume / distance entre les points : 20.891691525119313 / 34.776588877848894
# vitesse : 0.6007401012934415
# Force prop : 6.2752384414957545
# Force / angle 12.223961182100213 / 19.797838364770683
# Variation volume / distance entre les points : 7.364625087486274 / 34.38268050016109
# vitesse : 0.21419578056026697
# Force prop : 0.7887358095739234
# Force / angle 12.184887709023883 / 19.717974705013688
# Force / angle 12.211177045399888 / 19.771700311488914
# Force / angle 12.296206626294575 / 19.94569710515077
# Force / angle -12.434295014825892 / 20.229008970494412
# Force / angle -12.496065523600052 / 20.35603753146065
# Variation volume / distance entre les points : 1.3768389565047983 / 35.34204593487914
# vitesse : 0.03895753401038939
# Force prop : 0.02681912523743236
# Force / angle -12.489148143750082 / 20.341803142883283
# Variation volume / distance entre les points : 12.93867650138418 / 35.31683609925153
# vitesse : 0.3663600121206324
# Force prop : 2.370106839936025
# Force / angle -12.42023217828074 / 20.20011483866575
# Variation volume / distance entre les points : 23.254560167599266 / 35.072938300903274
# vitesse : 0.6630342735498829
# Force prop : 7.709285203723111
# Force / angle 12.295473431628581 / 19.944195275115625
# Variation volume / distance entre les points : 9.369951207941995 / 34.63360258554076
# vitesse : 0.2705450922929361
# Force prop : 1.2674971571664877
# Force / angle 12.244879035603965 / 19.840623350223552
# Force / angle 12.261179364975373 / 19.87397834717532
# Force / angle -12.33767211839249 / 20.030674474063154
# Force / angle -12.344340885255003 / 20.044348832134453
# Variation volume / distance entre les points : 10.455820916400626 / 34.80536385513267
# vitesse : 0.3004083209679973
# Force prop : 1.5705078029189894
# Force / angle 12.288099872554959 / 19.929093175765296
# Force / angle 12.299312693145039 / 19.952059664656275
# Force / angle -12.371367033521244 / 20.099788016715518
# Force / angle -12.374066453589313 / 20.105327307088412
# Variation volume / distance entre les points : 11.201550594743821 / 34.910497158382896
# vitesse : 0.32086482595548044
# Force prop : 1.7970917910069921
# Force / angle 12.314224808635991 / 19.982612543052404
# Force / angle 12.322210870124705 / 19.998979281646474
# Force / angle -12.391330932850126 / 20.140762799075105
# Variation volume / distance entre les points : 0.00937713114581129 / 34.97189003539779
# vitesse : 0.00026813338187670044
# Force prop : 1.2571609432138603e-06
# Force / angle -12.391321491980856 / 20.14074341770358
# Variation volume / distance entre les points : 11.670805022102286 / 34.97178714316294
# vitesse : 0.3337205780855827
# Force prop : 1.9473938993500484
# Force / angle -12.329083178324812 / 20.013065932834177
# Variation volume / distance entre les points : 22.086970108319292 / 34.75196726249908
# vitesse : 0.635560281853551
# Force prop : 7.018800473667182
# Force / angle 12.210803611751524 / 19.770936918939093
# Variation volume / distance entre les points : 8.37466256650805 / 34.33563846241816
# vitesse : 0.24390583491477755
# Force prop : 1.0213145327068398
# Force / angle 12.165731530973298 / 19.67884761519505
# Force / angle 12.186599101393199 / 19.721471138847164
# Force / angle 12.266876038278054 / 19.885638337682455
# Force / angle -12.40068096366524 / 20.15995978420997
# Force / angle -12.45858898611344 / 20.27894675964634
# Variation volume / distance entre les points : 1.9423224583897536 / 35.208980713344204
# vitesse : 0.05516554069551958
# Force prop : 0.0535746343110608
# Force / angle -12.44817757390247 / 20.25754198590986
# Variation volume / distance entre les points : 13.433198850309054 / 35.17224760219676
# vitesse : 0.3819260856525431
# Force prop : 2.56524452734539
# Force / angle -12.376301435805045 / 20.10991382169477
# Variation volume / distance entre les points : 23.730758287245408 / 34.918597646133435
# vitesse : 0.6796022717674384
# Force prop : 8.063738621387971
# Force / angle 12.249187334045471 / 19.849438080510666
# Variation volume / distance entre les points : 9.857528032671325 / 34.470935367782204
# vitesse : 0.28596636347398136
# Force prop : 1.4094607221729243
# Force / angle 12.19635165462031 / 19.74139863926543
# Force / angle 12.210347151278246 / 19.770003807752424
# Force / angle 12.284472173764433 / 19.921664091576638
# Force / angle -12.412779906804888 / 20.18480690959724
# Force / angle -12.465746812859962 / 20.29366551154421
# Variation volume / distance entre les points : 2.789766749541741 / 35.234509731877324
# vitesse : 0.07917711274460522
# Force prop : 0.11044283822980862
# Force / angle -12.450927145558783 / 20.263194313246455
# Variation volume / distance entre les points : 14.201521660786966 / 35.18199061572432
# vitesse : 0.40365884397796714
# Force prop : 2.8662849081606634
# Force / angle -12.375073080499064 / 20.107393024974158
# Variation volume / distance entre les points : 24.403074766147256 / 34.91407224379918
# vitesse : 0.6989466767366644
# Force prop : 8.52822400497749
# Force / angle 12.24431765495645 / 19.839474837539477
# Variation volume / distance entre les points : 10.454513915690768 / 34.45367631334216
# vitesse : 0.303436818196445
# Force prop : 1.586142219183832
# Force / angle 12.188141600656484 / 19.72462263929214
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 335
#     333     # === Mise à jour de l'affichage ===
#     334     pygame.display.flip()
# --> 335     clock.tick(100)
#     336     compteur +=1
#     338 # =======================
#     339 # FERMETURE
#     340 # =======================
#
# KeyboardInterrupt:
